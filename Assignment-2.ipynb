# %% [markdown]
# # Assignment 2:

# %% [markdown]
# ## Konda Sarvari Harshitha (21BCE9218)

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('car_crashes')

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
sns.scatterplot(x="speeding",y="total",data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='total'>

# %% [raw]
#  Inference: From the plot we can say that as speeding increases total is also increasing

# %%
sns.lineplot(x="no_previous",y="total",data=df)
# Out:
# <Axes: xlabel='no_previous', ylabel='total'>

# %% [raw]
# Inference:from the plot we can say that as no_previous increases total is also increasing

# %%
sns.distplot(df["total"])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1524\1102674835.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total"])
# <Axes: xlabel='total', ylabel='Density'>

# %% [raw]
# Inference:The distplot generates a distribution plot for the "total" variable in the DataFrame "df," providing a visual representation of its data distribution, including the shape, central tendency, and spread of the variable.

# %%
sns.relplot(x="speeding",y="total",data=df,hue="alcohol")

# %% [raw]
# Inference:The `relplot` displays a relational scatter plot with "speeding" on the x-axis and "total" on the y-axis in the DataFrame "df," where the color hue represents the "alcohol" variable. This plot helps visualize the relationship between speeding, total values, and how they may vary with different levels of alcohol.

# %%
sns.barplot(x="alcohol", y="speeding", data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %% [raw]
# Inference:The barplot illustrates the relationship between the "alcohol" variable on the x-axis and the "speeding" variable on the y-axis in the DataFrame "df," showing how different alcohol levels may correspond to varying levels of speeding behavior.

# %%
sns.countplot(x="alcohol" ,data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='count'>

# %% [raw]
# Inference:The countplot displays the frequency or count of each unique value in the "alcohol" column of the DataFrame "df," providing a visual representation of the distribution of alcohol values in the dataset.

# %%
sns.boxplot(x="abbrev", y="alcohol", data=df)
# Out:
# <Axes: xlabel='abbrev', ylabel='alcohol'>

# %% [raw]
# Inference: The plot shows the the distribution of the "alcohol" variable across different categories represented by the "abbrev" column, allowing for a comparison of central tendency and spread within each category.

# %%
corr=df.corr()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1524\1726683880.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()

# %%
corr
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %% [raw]
# Inference:from the plot we can say that how the attributes are correlated to each other.
#  >=0.5 - Highly Correlated
# <0.5 - poorly correlated
